# %% [markdown]
# # Exploratory Analysis
#
# This notebook is for exploring data and testing the model.

# %%
import torch
from utils.data_loader import load_dummy_data

data = load_dummy_data()
print('Input:', data['input'])
print('Target:', data['target'])
